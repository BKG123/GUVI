# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %% [markdown]
# # Assignment5

# %% [markdown]
# ## Ground Cricket Chirps
#
# In _The Song of Insects_ (1948) by George W. Pierce, Pierce mechanically measured the frequency (the number of wing vibrations per second) of chirps (or pulses of sound) made by a striped ground cricket, at various ground temperatures.  Since crickets are ectotherms (cold-blooded), the rate of their physiological processes and their overall metabolism are influenced by temperature.  Consequently, there is reason to believe that temperature would have a profound effect on aspects of their behavior, such as chirp frequency.
#
# In general, it was found that crickets did not sing at temperatures colder than 60º F. or warmer than 100º F.

# %%
ground_cricket_data = {"Chirps/Second": [20.0, 16.0, 19.8, 18.4, 17.1, 15.5, 14.7,
                                         15.7, 15.4, 16.3, 15.0, 17.2, 16.0, 17.0,
                                         14.4],
                       "Ground Temperature": [88.6, 71.6, 93.3, 84.3, 80.6, 75.2, 69.7,
                                              71.6, 69.4, 83.3, 79.6, 82.6, 80.6, 83.5,
                                              76.3]}
df = pd.DataFrame(ground_cricket_data)

# %% [markdown]
# ### Tasks
#
# 1. Find the linear regression equation for this data.
# 2. Chart the original data and the equation on the chart.
# 3. Find the equation's $R^2$ score (use the `.score` method) to determine whether the
# equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)
# 4. Extrapolate data:  If the ground temperature reached 95, then at what approximate rate would you expect the crickets to be chirping?
# 5. Interpolate data:  With a listening device, you discovered that on a particular morning the crickets were chirping at a rate of 18 chirps per second.  What was the approximate ground temperature that morning?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler 
from sklearn.linear_model import LinearRegression

# %%
df
# Out:
#     Chirps/Second  Ground Temperature
# 0            20.0                88.6
# 1            16.0                71.6
# 2            19.8                93.3
# 3            18.4                84.3
# 4            17.1                80.6
# 5            15.5                75.2
# 6            14.7                69.7
# 7            15.7                71.6
# 8            15.4                69.4
# 9            16.3                83.3
# 10           15.0                79.6
# 11           17.2                82.6
# 12           16.0                80.6
# 13           17.0                83.5
# 14           14.4                76.3

# %%
#Find the linear regression equation for this data.
linreg = LinearRegression()
X = np.array(df['Chirps/Second']).reshape(15,1)
linreg.fit(X,df['Ground Temperature'])
print(linreg.coef_,linreg.intercept_)
# Out:
# [3.410323] 22.848982308066887

# %% [markdown]
# equation of line: Y = 3.410323X + 22.84892

# %%
#Chart the original data and the equation on the chart.
pred = linreg.predict(X)
plt.scatter(df['Chirps/Second'], df['Ground Temperature'], color="black")
plt.plot(df['Chirps/Second'], pred, color="blue", linewidth=3)

# %%
#Find the equation's  R2  score (use the .score method) to determine whether the equation is a good fit for this data. 
#(0.8 and greater is considered a strong correlation.)
linreg.score(X,df['Ground Temperature'])
# Out:
# 0.6922946529147003

# %%
#Extrapolate data: If the ground temperature reached 95, then at what approximate rate would you expect the crickets to be chirping?
Y = 95
X = (Y - linreg.intercept_)/linreg.coef_
print(f'Crickets chirping rate at 95deg F = {X[0]}')
# Out:
# Crickets chirping rate at 95deg F = 21.156652229784402

# %%
#Interpolate data: With a listening device, you discovered that on a particular morning the crickets were chirping at a rate of 18 chirps per second. 
#What was the approximate ground temperature that morning?
X = 18
Y = linreg.coef_*X + linreg.intercept_
print(f'Temp when crickets chirping rate per sec 18  = {Y[0]} deg F')
# Out:
# Temp when crickets chirping rate per sec 18  = 84.23479629930205 deg F

# %% [markdown]
# # Assignment6

# %% [markdown]
# ## Brain vs. Body Weight
#
# In the file `brain_body.txt`, the average brain and body weight for a number of mammal species are recorded. Load this data into a Pandas data frame.
#
# ### Tasks
#
# 1. Find the linear regression equation for this data for brain weight to body weight.
# 2. Chart the original data and the equation on the chart.
# 3. Find the equation's $R^2$ score (use the `.score` method) to determine whether the
# equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)

# %%
df = pd.read_fwf("brain_body.txt")
df
# Out:
#       Brain   Body
# 0     3.385   44.5
# 1     0.480   15.5
# 2     1.350    8.1
# 3   465.000  423.0
# 4    36.330  119.5
# ..      ...    ...
# 57  160.000  169.0
# 58    0.900    2.6
# 59    1.620   11.4
# 60    0.104    2.5
# 61    4.235   50.4
#
# [62 rows x 2 columns]

# %%
#Find the linear regression equation for this data.
linreg = LinearRegression()
X = np.array(df['Brain']).reshape(62,1)
linreg.fit(X,df['Body'])
print(linreg.coef_,linreg.intercept_)
# Out:
# [0.96649637] 91.00439620740687

# %% [markdown]
# equation of line: Y = 0.96649637X + 91.00439620740687

# %%
#Chart the original data and the equation on the chart.

pred = linreg.predict(X)
plt.scatter(df['Brain'], df['Body'], color="black")
plt.plot(df['Brain'], pred, color="blue", linewidth=3)

# %%
#Find the equation's  R2  score (use the .score method) to determine whether the equation is a good fit for this data. 
#(0.8 and greater is considered a strong correlation.)
linreg.score(X,df['Body'])
# Out:
# 0.8726620843043331

# %% [markdown]
# # Assignment7

# %% [markdown]
# ## Salary Discrimination
#
# The file `salary.txt` contains data for 52 tenure-track professors at a small Midwestern college. This data was used in legal proceedings in the 1980s about discrimination against women in salary.
#
# The data in the file, by column:
#
# 1. Sex. 1 for female, 0 for male.
# 2. Rank. 1 for assistant professor, 2 for associate professor, 3 for full professor.
# 3. Year. Number of years in current rank.
# 4. Degree. Highest degree. 1 for doctorate, 0 for master's.
# 5. YSdeg. Years since highest degree was earned.
# 6. Salary. Salary/year in dollars.
#
# ### Tasks
#
# 1. Find the linear regression equation for this data using columns 1-5 to column 6.
# 2. Find the selection of columns with the best $R^2$ score.
# 3. Report whether sex is a factor in salary.

# %%
df = pd.read_fwf("salary.txt", header=None, 
                 names=["Sex", "Rank", "Year", "Degree", "YSdeg", "Salary"])
df
# Out:
#     Sex  Rank  Year  Degree  YSdeg  Salary
# 0     0     3    25       1     35   36350
# 1     0     3    13       1     22   35350
# 2     0     3    10       1     23   28200
# 3     1     3     7       1     27   26775
# 4     0     3    19       0     30   33696
# 5     0     3    16       1     21   28516
# 6     1     3     0       0     32   24900
# 7     0     3    16       1     18   31909
# 8     0     3    13       0     30   31850
# 9     0     3    13       0     31   32850
# 10    0     3    12       1     22   27025
# 11    0     2    15       1     19   24750
# 12    0     3     9       1     17   28200
# 13    0     2     9       0     27   23712
# 14    0     3     9       1     24   25748
# 15    0     3     7       1     15   29342
# 16    0     3    13       1     20   31114
# 17    0     2    11       0     14   24742
# 18    0     2    10       0     15   22906
# 19    0     3     6       0     21   24450
# 20    0     1    16       0     23   19175
# ...

# %%
#Find the linear regression equation for this data using columns 1-5 to column 6.
scores = {}
equations = []
y=df['Salary']
for i in df.columns:
  linreg = LinearRegression()
  X = np.array(df[i]).reshape(52,1)
  linreg.fit(X,y)
  s = f'Y = {linreg.coef_}X + {linreg.intercept_}'
  equations.append(s)
  scores[i] = linreg.score(X,y)

# %%
equations
# Out:
# ['Y = [-3339.64661654]X + 24696.78947368421',
#  'Y = [5952.77890467]X + 11663.1430020284',
#  'Y = [752.79775742]X + 18166.147545466978',
#  'Y = [-858.86928105]X + 24359.222222222223',
#  'Y = [390.64512637]X + 17502.257386585068',
#  'Y = [1.]X + -1.0913936421275139e-11']

# %%
#Find the selection of columns with the best  R2  score.
scores
# Out:
# {'Degree': 0.004861680984748373,
#  'Rank': 0.7525360539274633,
#  'Salary': 1.0,
#  'Sex': 0.06389892583288004,
#  'YSdeg': 0.45542813458360276,
#  'Year': 0.49093702676921624}

# %% [markdown]
# Rank has the best R2 score

# %%
#Report whether sex is a factor in salary.
# From the above scores dictionary we can see that sex is definitely a factor in salary even if its a smaller factor
#compared to others
